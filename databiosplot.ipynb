# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('./data/databeforeplot_row.csv')
print(df)
df[['name', 'height_cm']].plot(title="BIRTH LOCATION = CUBA",xlabel='Name', ylabel='Height_cm')
# Out:
#     athlete_id             name   born_date              born_city  \
# 0         1487   Rolando Arrojo  1965-07-18  San Juan de los Yeras
# 1         1489   José Contreras  1971-12-06           Las Martinas
# 2         1500  Pedro Luis Lazo  1973-04-15          Pinar del Río
# 3         1511    Ormari Romero  1968-02-22       Santiago de Cuba
# 4         1512    Antonio Scull  1965-09-10  San Miguel del Padrón
# ..         ...              ...         ...                    ...
# 85      135631    Rafael Capote  1987-10-05     La Habana (Havana)
# 86      136134  Yasmani Copello  1987-04-15     La Habana (Havana)
# 87      141286      Yoandy Leal  1988-08-31     La Habana (Havana)
# 88      146039   Daymaro Salina  1987-09-01               Artemisa
# 89      146049  Victor Iturriza  1990-05-22     La Habana (Havana)
#
#             born_region born_country           NOC  height_cm  weight_kg  \
# 0           Villa Clara          CUB          Cuba      193.0      100.0
# 1         Pinar del Río          CUB          Cuba      191.0      107.0
# 2         Pinar del Río          CUB          Cuba      192.0      107.0
# 3      Santiago de Cuba          CUB          Cuba      196.0       86.0
# 4   Ciudad de La Habana          CUB          Cuba      195.0       96.0
# ..                  ...          ...           ...        ...        ...
# 85  Ciudad de La Habana          CUB         Qatar      196.0      109.0
# 86  Ciudad de La Habana          CUB  Cuba Türkiye      191.0       85.0
# 87  Ciudad de La Habana          CUB        Brazil      201.0      104.0
# 88             Artemisa          CUB      Portugal      200.0      118.0
# 89  Ciudad de La Habana          CUB      Portugal      194.0      120.0
#
#    died_date
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ..       ...
# 85       NaN
# 86       NaN
# 87       NaN
# 88       NaN
# 89       NaN
#
# [90 rows x 10 columns]
# <Axes: title={'center': 'BIRTH LOCATION = CUBA'}, xlabel='Name', ylabel='Height_cm'>
