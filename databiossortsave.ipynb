# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
df = pd.read_csv('./data/bios.csv')
new=df[df['height_cm'] > 190]
print(new)
new.to_csv('cleaned_row.csv', index=False)
# Out:
#         athlete_id                 name   born_date       born_city  \
# 79              80           Neil Broad  1966-11-20       Cape Town
# 105            106        Harold Mahony  1867-02-13       Edinburgh
# 137            138         Boris Becker  1967-11-22          Leimen
# 143            144  Marc-Kevin Goellner  1970-09-22  Rio de Janeiro
# 160            161        Michael Stich  1968-10-18       Pinneberg
# ...            ...                  ...         ...             ...
# 145257      148977        Pavol Regenda  1999-12-07      Michalovce
# 145259      148979     Juraj Slafkovský  2004-03-30          Košice
# 145261      148981          Matej Tomek  1997-05-24      Bratislava
# 145263      148983        Marián Skupek  2001-07-12         Gelnica
# 145459      149186      Roberts Mamčics  1995-04-06         Liepāja
#
#                born_region born_country            NOC  height_cm  weight_kg  \
# 79            Western Cape          RSA  Great Britain      191.0       87.0
# 105               Scotland          GBR  Great Britain      191.0        NaN
# 137      Baden-Württemberg          GER        Germany      192.0       85.0
# 143         Rio de Janeiro          BRA        Germany      196.0       85.0
# 160     Schleswig-Holstein          GER        Germany      192.0       79.0
# ...                    ...          ...            ...        ...        ...
# 145257              Košice          SVK       Slovakia      192.0       93.0
# 145259              Košice          SVK       Slovakia      192.0      102.0
# 145261          Bratislava          SVK       Slovakia      191.0       82.0
# 145263              Košice          SVK       Slovakia      196.0      108.0
# 145459             Liepāja          LAT         Latvia      196.0      105.0
#
#          died_date
# 79             NaN
# 105     1905-06-27
# 137            NaN
# 143            NaN
# 160            NaN
# ...            ...
# 145257         NaN
# 145259         NaN
# 145261         NaN
# 145263         NaN
# 145459         NaN
#
# [8673 rows x 10 columns]
# <Axes: title={'center': 'Weight check'}, xlabel='Love', ylabel='Joy'>
